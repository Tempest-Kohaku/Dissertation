# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
import shap
import matplotlib.pyplot as plt
import cv2

# Configuration
SEED = 42
IMG_SIZE = 224
BATCH_SIZE = 8

MODEL_PATH = "outputs/models/best_densenet121_tb.pth"
TRAIN_CSV = "outputs/train_split.csv"
TEST_CSV = "outputs/test_split.csv"

OUTPUT_DIR = "outputs/shap"
HEATMAP_DIR = os.path.join(OUTPUT_DIR, "shap_heatmaps")
LOCAL_DIR = os.path.join(OUTPUT_DIR, "shap_local_examples")

os.makedirs(OUTPUT_DIR, exist_ok = True)
os.makedirs(HEATMAP_DIR, exist_ok = True)
os.makedirs(LOCAL_DIR, exist_ok = True)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)

# Reproducibility
def set_seed(seed = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
set_seed(SEED)

# Dataset Class
class TBXrayDataset(Dataset):
    def __init__(self, dataframe, transform = None):
        self.df = dataframe.reset_index(drop = True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        image_path = row["image_path"]
        label = int(row["label"])
        image_id = row["image_id"]
        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image_tensor = self.transform(image)
        else:
            image_tensor = image
        return image_tensor, label, image_id, image_path

# Transform
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Load Data
train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

train_dataset = TBXrayDataset(train_df, transform = transform)
test_dataset = TBXrayDataset(test_df, transform = transform)

train_loader = DataLoader(
    train_dataset,
    batch_size = BATCH_SIZE,
    shuffle = True,
    num_workers = 0
)

test_loader = DataLoader(
    test_dataset,
    batch_size = BATCH_SIZE,
    shuffle = False,
    num_workers = 0
)

# Load DenseNet121 Model
model = models.densenet121(weights = None)
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)
model.load_state_dict(torch.load(MODEL_PATH, map_location = DEVICE))
model = model.to(DEVICE)
model.eval()

# Wrapper: output only TB logit, preserving 2D shape
class TBLogitModel(nn.Module):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model

    def forward(self, x):
        outputs = self.base_model(x)
        return outputs[:, 1:2]
wrapped_model = TBLogitModel(model).to(DEVICE)
wrapped_model.eval()

# Select Background Samples
background_images = []
for images, labels, image_ids, image_paths in train_loader:
    background_images.append(images)
    if len(background_images) * BATCH_SIZE >= 50:
        break

background = torch.cat(background_images, dim = 0)[:50].to(DEVICE)
print("Background shape:", background.shape)

# Select Test Samples to Explain
test_images = []
test_labels = []
test_ids = []
test_paths = []

for images, labels, image_ids, image_paths in test_loader:
    test_images.append(images)
    test_labels.extend(labels.numpy())
    test_ids.extend(image_ids)
    test_paths.extend(image_paths)

    if len(test_labels) >= 40:
        break
test_images = torch.cat(test_images, dim = 0)[:40].to(DEVICE)
test_labels = np.array(test_labels[:40])
test_ids = test_ids[:40]
test_paths = test_paths[:40]
print("Test explanation shape:", test_images.shape)

# Run SHAP GradientExplainer
print("Creating SHAP GradientExplainer...")
explainer = shap.GradientExplainer(
    wrapped_model,
    background
)
print("Generating SHAP values...")
shap_values = explainer.shap_values(test_images)

# Handle SHAP version-dependent return formats
if isinstance(shap_values, list):
    shap_values = shap_values[0]
shap_values = np.asarray(shap_values)
print("Raw SHAP values shape:", shap_values.shape)
if shap_values.ndim == 5 and shap_values.shape[-1] == 1:
    shap_values = shap_values[..., 0]
print("Final SHAP values shape:", shap_values.shape)

# Save SHAP values
np.save(os.path.join(OUTPUT_DIR, "shap_values.npy"),shap_values)

# Save explanation metadata
meta_df = pd.DataFrame({"image_id": test_ids, "image_path": test_paths, "true_label": test_labels})

meta_df.to_csv(os.path.join(OUTPUT_DIR, "shap_metadata.csv"),index = False)
# Helper Functions
def denormalize_image(tensor):
    """
    Convert normalised torch tensor back to displayable image.
    """
    image = tensor.detach().cpu().numpy().transpose(1, 2, 0)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    return image

def shap_to_heatmap(shap_value):
    """
    Convert SHAP values to a 2D heatmap.
    Input shape expected: C x H x W or H x W x C.
    """
    if shap_value.shape[0] == 3:
        shap_abs = np.abs(shap_value).mean(axis = 0)
    else:
        shap_abs = np.abs(shap_value).mean(axis=-1)

    shap_abs = shap_abs - shap_abs.min()
    shap_abs = shap_abs / (shap_abs.max() + 1e-8)
    return shap_abs

def save_shap_overlay(original_image, heatmap, save_path, title):
    """
    Save image with SHAP heatmap overlay.
    """
    heatmap_resized = cv2.resize(heatmap, (original_image.shape[1], original_image.shape[0]))
    heatmap_uint8 = np.uint8(255 * heatmap_resized)
    heatmap_color = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB) / 255.0
    overlay = 0.55 * original_image + 0.45 * heatmap_color
    overlay = np.clip(overlay, 0, 1)

    plt.figure(figsize=(6, 6))
    plt.imshow(overlay)
    plt.axis("off")
    plt.title(title)
    plt.tight_layout()
    plt.savefig(save_path, dpi = 300)
    plt.close()

# Save Local SHAP Heatmaps
test_images_cpu = test_images.detach().cpu()

for i in range(len(test_ids)):
    original = denormalize_image(test_images_cpu[i])
    heatmap = shap_to_heatmap(shap_values[i])

    save_path = os.path.join(
        HEATMAP_DIR,
        f"{test_ids[i]}_shap_overlay.png"
    )
    title = f"SHAP Explanation | ID: {test_ids[i]} | True Label: {test_labels[i]}"
    save_shap_overlay(original, heatmap, save_path, title)
print("Saved local SHAP heatmaps.")

# Create Global SHAP Importance Map
global_shap = np.mean(np.abs(shap_values), axis = 0)
global_heatmap = shap_to_heatmap(global_shap)

plt.figure(figsize=(6, 6))
plt.imshow(global_heatmap, cmap="hot")
plt.axis("off")
plt.title("Global SHAP Importance Map")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "shap_global_importance_map.png"), dpi = 300)
plt.close()

np.save(os.path.join(OUTPUT_DIR, "shap_global_importance.npy"), global_heatmap)
print("Saved global SHAP importance map.")
# Out:
# Using device: cuda
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 98
#      96 num_features = model.classifier.in_features
#      97 model.classifier = nn.Linear(num_features, 2)
# ---> 98 model.load_state_dict(torch.load(MODEL_PATH, map_location = DEVICE))
#      99 model = model.to(DEVICE)
#     100 model.eval()
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:1570, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1568 if weights_only:
#    1569     try:
# -> 1570         return _load(
#    1571             opened_zipfile,
#    1572             map_location,
#    1573             _weights_only_unpickler,
#    1574             overall_storage=overall_storage,
#    1575             **pickle_load_args,
#    1576         )
#    1577     except pickle.UnpicklingError as e:
#    1578         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:2190, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2188 global _serialization_tls
#    2189 _serialization_tls.map_location = map_location
# -> 2190 result = unpickler.load()
#    2191 _serialization_tls.map_location = None
#    2193 torch._utils._validate_loaded_sparse_tensors()
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\_weights_only_unpickler.py:541, in Unpickler.load(self)
#     533     if (
#     534         type(pid) is tuple
#     535         and len(pid) > 0
#     536         and torch.serialization._maybe_decode_ascii(pid[0]) != "storage"
#     537     ):
#     538         raise UnpicklingError(
#     539             f"Only persistent_load of storage is allowed, but got {type(pid[0])}"
#     540         )
# --> 541     self.append(self.persistent_load(pid))
#     542 elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     543     idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:2154, in _load.<locals>.persistent_load(saved_id)
#    2152 else:
#    2153     nbytes = numel * torch._utils._element_size(dtype)
# -> 2154     typed_storage = load_tensor(
#    2155         dtype, nbytes, key, _maybe_decode_ascii(location)
#    2156     )
#    2158 return typed_storage
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:2116, in _load.<locals>.load_tensor(dtype, nbytes, key, location)
#    2114     wrap_storage = storage
#    2115 elif torch._guards.detect_fake_mode(None) is None:
# -> 2116     wrap_storage = restore_location(storage, location)
#    2117 else:
#    2118     storage._fake_device = location
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:1920, in _get_restore_location.<locals>.restore_location(storage, location)
#    1919 def restore_location(storage, location):
# -> 1920     return default_restore_location(storage, str(map_location))
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:734, in default_restore_location(storage, location)
#     714 """
#     715 Restores `storage` using a deserializer function registered for the `location`.
#     716
#    (...)
#     731        all matching ones return `None`.
#     732 """
#     733 for _, _, fn in _package_registry:
# --> 734     result = fn(storage, location)
#     735     if result is not None:
#     736         return result
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\serialization.py:668, in _deserialize(backend_name, obj, location)
#     664 if location == backend_name or bool(
#     665     re.match(f"{backend_name}(:|[0-9]+)", location)
#     666 ):
#     667     device = _validate_device(location, backend_name)
# --> 668     return obj.to(device=device)
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\storage.py:289, in _StorageBase.to(self, device, non_blocking)
#     287 if not isinstance(device, torch.device):
#     288     device = torch.device(device)
# --> 289 return _to(self, device, non_blocking)
#
# File ~\anaconda3\envs\AML_Diabetic\lib\site-packages\torch\_utils.py:106, in _to(self, device, non_blocking)
#     102 if self.is_sparse:
#     103     raise AssertionError(
#     104         f"sparse storage is not supported for {device.type.upper()} tensors"
#     105     )
# --> 106 untyped_storage = torch.UntypedStorage(self.size(), device=device)
#     107 untyped_storage.copy_(self, non_blocking)
#     108 return untyped_storage
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 10.66 GiB is allocated by PyTorch, and 190.22 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
